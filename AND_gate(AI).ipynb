# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import sys
import matplotlib.pyplot as plt

# %%
training_data = np.array([[0,0], [0,1], [1,0], [1,1]], "float32")
target_data = np.array([[0], [0], [0], [1]], "float32")

# %%
my_model = tf.keras.models.Sequential()
my_model.add(tf.keras.layers.Dense(4, input_dim=2, activation='relu'))
my_model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# %%
my_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['binary_accuracy'])
my_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 4)                 12
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = my_model.fit(training_data, target_data, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 1/1 - 0s - loss: 0.2500 - binary_accuracy: 0.7500
# Epoch 2/100
# 1/1 - 0s - loss: 0.2495 - binary_accuracy: 0.7500
# Epoch 3/100
# 1/1 - 0s - loss: 0.2491 - binary_accuracy: 0.7500
# Epoch 4/100
# 1/1 - 0s - loss: 0.2486 - binary_accuracy: 0.7500
# Epoch 5/100
# 1/1 - 0s - loss: 0.2481 - binary_accuracy: 0.7500
# Epoch 6/100
# 1/1 - 0s - loss: 0.2476 - binary_accuracy: 0.7500
# Epoch 7/100
# 1/1 - 0s - loss: 0.2471 - binary_accuracy: 0.7500
# Epoch 8/100
# 1/1 - 0s - loss: 0.2466 - binary_accuracy: 0.7500
# Epoch 9/100
# 1/1 - 0s - loss: 0.2461 - binary_accuracy: 0.7500
# Epoch 10/100
# 1/1 - 0s - loss: 0.2457 - binary_accuracy: 0.7500
# Epoch 11/100
# 1/1 - 0s - loss: 0.2452 - binary_accuracy: 0.7500
# Epoch 12/100
# 1/1 - 0s - loss: 0.2447 - binary_accuracy: 0.7500
# Epoch 13/100
# 1/1 - 0s - loss: 0.2442 - binary_accuracy: 0.7500
# Epoch 14/100
# 1/1 - 0s - loss: 0.2437 - binary_accuracy: 0.7500
# Epoch 15/100
# 1/1 - 0s - loss: 0.2432 - binary_accuracy: 0.7500
# Epoch 16/100
# 1/1 - 0s - loss: 0.2428 - binary_accuracy: 0.7500
# Epoch 17/100
# 1/1 - 0s - loss: 0.2423 - binary_accuracy: 0.7500
# Epoch 18/100
# 1/1 - 0s - loss: 0.2418 - binary_accuracy: 0.7500
# Epoch 19/100
# 1/1 - 0s - loss: 0.2413 - binary_accuracy: 0.7500
# Epoch 20/100
# 1/1 - 0s - loss: 0.2409 - binary_accuracy: 0.7500
# Epoch 21/100
# 1/1 - 0s - loss: 0.2404 - binary_accuracy: 0.7500
# Epoch 22/100
# 1/1 - 0s - loss: 0.2399 - binary_accuracy: 0.7500
# Epoch 23/100
# 1/1 - 0s - loss: 0.2395 - binary_accuracy: 0.7500
# Epoch 24/100
# 1/1 - 0s - loss: 0.2390 - binary_accuracy: 0.7500
# Epoch 25/100
# 1/1 - 0s - loss: 0.2385 - binary_accuracy: 0.7500
# Epoch 26/100
# 1/1 - 0s - loss: 0.2381 - binary_accuracy: 0.7500
# Epoch 27/100
# 1/1 - 0s - loss: 0.2376 - binary_accuracy: 0.7500
# Epoch 28/100
# 1/1 - 0s - loss: 0.2371 - binary_accuracy: 0.7500
# Epoch 29/100
# 1/1 - 0s - loss: 0.2367 - binary_accuracy: 0.7500
# Epoch 30/100
# 1/1 - 0s - loss: 0.2362 - binary_accuracy: 0.7500
# Epoch 31/100
# 1/1 - 0s - loss: 0.2358 - binary_accuracy: 0.7500
# Epoch 32/100
# 1/1 - 0s - loss: 0.2353 - binary_accuracy: 0.7500
# Epoch 33/100
# 1/1 - 0s - loss: 0.2349 - binary_accuracy: 1.0000
# Epoch 34/100
# 1/1 - 0s - loss: 0.2344 - binary_accuracy: 1.0000
# Epoch 35/100
# 1/1 - 0s - loss: 0.2339 - binary_accuracy: 1.0000
# Epoch 36/100
# 1/1 - 0s - loss: 0.2335 - binary_accuracy: 1.0000
# Epoch 37/100
# 1/1 - 0s - loss: 0.2330 - binary_accuracy: 1.0000
# Epoch 38/100
# 1/1 - 0s - loss: 0.2326 - binary_accuracy: 1.0000
# Epoch 39/100
# 1/1 - 0s - loss: 0.2322 - binary_accuracy: 1.0000
# Epoch 40/100
# 1/1 - 0s - loss: 0.2317 - binary_accuracy: 1.0000
# Epoch 41/100
# 1/1 - 0s - loss: 0.2313 - binary_accuracy: 1.0000
# Epoch 42/100
# 1/1 - 0s - loss: 0.2308 - binary_accuracy: 1.0000
# Epoch 43/100
# 1/1 - 0s - loss: 0.2304 - binary_accuracy: 1.0000
# Epoch 44/100
# 1/1 - 0s - loss: 0.2299 - binary_accuracy: 1.0000
# Epoch 45/100
# 1/1 - 0s - loss: 0.2295 - binary_accuracy: 1.0000
# Epoch 46/100
# 1/1 - 0s - loss: 0.2291 - binary_accuracy: 1.0000
# Epoch 47/100
# 1/1 - 0s - loss: 0.2286 - binary_accuracy: 1.0000
# Epoch 48/100
# 1/1 - 0s - loss: 0.2282 - binary_accuracy: 1.0000
# Epoch 49/100
# 1/1 - 0s - loss: 0.2278 - binary_accuracy: 1.0000
# Epoch 50/100
# 1/1 - 0s - loss: 0.2273 - binary_accuracy: 1.0000
# Epoch 51/100
# 1/1 - 0s - loss: 0.2269 - binary_accuracy: 1.0000
# Epoch 52/100
# 1/1 - 0s - loss: 0.2265 - binary_accuracy: 1.0000
# Epoch 53/100
# 1/1 - 0s - loss: 0.2260 - binary_accuracy: 1.0000
# Epoch 54/100
# 1/1 - 0s - loss: 0.2256 - binary_accuracy: 1.0000
# Epoch 55/100
# 1/1 - 0s - loss: 0.2252 - binary_accuracy: 1.0000
# Epoch 56/100
# 1/1 - 0s - loss: 0.2248 - binary_accuracy: 1.0000
# Epoch 57/100
# 1/1 - 0s - loss: 0.2243 - binary_accuracy: 1.0000
# Epoch 58/100
# 1/1 - 0s - loss: 0.2239 - binary_accuracy: 1.0000
# Epoch 59/100
# 1/1 - 0s - loss: 0.2235 - binary_accuracy: 1.0000
# Epoch 60/100
# 1/1 - 0s - loss: 0.2231 - binary_accuracy: 1.0000
# Epoch 61/100
# 1/1 - 0s - loss: 0.2227 - binary_accuracy: 1.0000
# Epoch 62/100
# 1/1 - 0s - loss: 0.2222 - binary_accuracy: 1.0000
# Epoch 63/100
# 1/1 - 0s - loss: 0.2218 - binary_accuracy: 1.0000
# Epoch 64/100
# 1/1 - 0s - loss: 0.2214 - binary_accuracy: 1.0000
# Epoch 65/100
# 1/1 - 0s - loss: 0.2210 - binary_accuracy: 1.0000
# Epoch 66/100
# 1/1 - 0s - loss: 0.2206 - binary_accuracy: 1.0000
# Epoch 67/100
# 1/1 - 0s - loss: 0.2202 - binary_accuracy: 1.0000
# Epoch 68/100
# 1/1 - 0s - loss: 0.2198 - binary_accuracy: 1.0000
# Epoch 69/100
# 1/1 - 0s - loss: 0.2193 - binary_accuracy: 1.0000
# Epoch 70/100
# 1/1 - 0s - loss: 0.2189 - binary_accuracy: 1.0000
# Epoch 71/100
# 1/1 - 0s - loss: 0.2185 - binary_accuracy: 1.0000
# Epoch 72/100
# 1/1 - 0s - loss: 0.2181 - binary_accuracy: 1.0000
# Epoch 73/100
# 1/1 - 0s - loss: 0.2177 - binary_accuracy: 1.0000
# Epoch 74/100
# 1/1 - 0s - loss: 0.2173 - binary_accuracy: 1.0000
# Epoch 75/100
# 1/1 - 0s - loss: 0.2169 - binary_accuracy: 1.0000
# Epoch 76/100
# 1/1 - 0s - loss: 0.2165 - binary_accuracy: 1.0000
# Epoch 77/100
# 1/1 - 0s - loss: 0.2161 - binary_accuracy: 1.0000
# Epoch 78/100
# 1/1 - 0s - loss: 0.2157 - binary_accuracy: 1.0000
# Epoch 79/100
# 1/1 - 0s - loss: 0.2153 - binary_accuracy: 1.0000
# Epoch 80/100
# 1/1 - 0s - loss: 0.2149 - binary_accuracy: 1.0000
# Epoch 81/100
# 1/1 - 0s - loss: 0.2145 - binary_accuracy: 1.0000
# Epoch 82/100
# 1/1 - 0s - loss: 0.2141 - binary_accuracy: 1.0000
# Epoch 83/100
# 1/1 - 0s - loss: 0.2137 - binary_accuracy: 1.0000
# Epoch 84/100
# 1/1 - 0s - loss: 0.2133 - binary_accuracy: 1.0000
# Epoch 85/100
# 1/1 - 0s - loss: 0.2129 - binary_accuracy: 1.0000
# Epoch 86/100
# 1/1 - 0s - loss: 0.2125 - binary_accuracy: 1.0000
# Epoch 87/100
# 1/1 - 0s - loss: 0.2121 - binary_accuracy: 1.0000
# Epoch 88/100
# 1/1 - 0s - loss: 0.2117 - binary_accuracy: 1.0000
# Epoch 89/100
# 1/1 - 0s - loss: 0.2113 - binary_accuracy: 1.0000
# Epoch 90/100
# 1/1 - 0s - loss: 0.2109 - binary_accuracy: 1.0000
# Epoch 91/100
# 1/1 - 0s - loss: 0.2105 - binary_accuracy: 1.0000
# Epoch 92/100
# 1/1 - 0s - loss: 0.2101 - binary_accuracy: 1.0000
# Epoch 93/100
# 1/1 - 0s - loss: 0.2097 - binary_accuracy: 1.0000
# Epoch 94/100
# 1/1 - 0s - loss: 0.2093 - binary_accuracy: 1.0000
# Epoch 95/100
# 1/1 - 0s - loss: 0.2089 - binary_accuracy: 1.0000
# Epoch 96/100
# 1/1 - 0s - loss: 0.2085 - binary_accuracy: 1.0000
# Epoch 97/100
# 1/1 - 0s - loss: 0.2081 - binary_accuracy: 1.0000
# Epoch 98/100
# 1/1 - 0s - loss: 0.2077 - binary_accuracy: 1.0000
# Epoch 99/100
# 1/1 - 0s - loss: 0.2073 - binary_accuracy: 1.0000
# Epoch 100/100
# 1/1 - 0s - loss: 0.2069 - binary_accuracy: 1.0000

# %%
print(my_model.predict(training_data).round())
# Out:
# [[0.]
#  [0.]
#  [0.]
#  [1.]]

# %%
loss_curver = history.history['loss']
acc_curver = history.history['binary_accuracy']
plt.plot(loss_curver, label='Train')
plt.legend(loc='lower left')
plt.title('Loss')
plt.show()

# %%
plt.plot(acc_curver, label='Train')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.show()

# %%
test_data = np.array([[1,1],[0,1],[1,0],[1,0]])
history2 = my_model.evaluate(test_data, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.0000e+00 - binary_accuracy: 0.0000e+00

# %%
print(history2)
# Out:
# [0.0, 0.0]
